# %% [markdown]
# # 02 — Results Analysis
#
# Visualize sparsity sweeps for each (architecture, pruning-variant, dataset) triple and answer the core question: how do node degree and homophily mediate activation-aware pruning robustness?
#
# **Architectures:** GCN, GAT, GraphSAGE.
# **Variants:** no-prune, magnitude, Wanda-Uniform, Wanda-Degree-Weighted, Wanda-Per-Class.
# **Sparsity grid:** 10%–90%.
# **Metrics:** accuracy (balanced datasets); F1 + recall (Ethereum AML).
#
# Reads from runs produced under `experiments/scripts/` and writes the figures referenced in the final report.
